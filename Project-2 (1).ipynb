# %% [markdown]
# # Wheelchair Control
#
# ![](images/wheelchair.jpg)

# %% [markdown]
# ### Python Dependencies

# %%
from numpy import *
from numpy.linalg import *

from scipy.linalg import *
from scipy.integrate import *
from scipy.signal import *

from matplotlib.pyplot import *

# %% [markdown]
# Step 1 - Wheelchair Planar Model
# ================================

# %% [markdown]
# ### Introduction

# %% [markdown]
# We consider a simple model of a wheelchair evolving in the plane. It is mainly made of
#
#   - A frame ; from above, its most visible component is the seat. We assume that it is a square,
#
#   - Two fixed wheels (their orientation with respect to the frame does not change).
#     They are parallel and located at opposite ends of the seat.
#
# We assume that the seat backrest is on top of the wheels common axis.
#
#
# Let $(0, e_x, e_y)$ be a direct orthonormal frame of the plane. We denote
#
#   - $(x, y)$ the coordinates of the wheel axis center in the orthonormal and
#   - $\theta$ the angle of the wheels direction with respect to vector $e_x$ ; with $\theta = 0$ when the front of the wheelchait faces the right ($e_x$) and $\theta = \pi/2$ when it faces upwards ($e_y$).
#
#   - $\phi_l$ and $\phi_r$ the rotation angles of the left and right wheel respectively ; by convention, when these angles increase, the wheelchair moves forward.

# %% [markdown]
# ### Parameter Definition

# %% [markdown]
# From now on, we assume that the seat side length is $L = 50 \mbox{ cm}$ and the wheel radius is $R_w = 30 \mbox{ cm}$.
#
# 🧩 Define the corresponding Python variables `L` and `Rw` (express every length in meters, and more generally in the sequel, always use the [international standard of units](https://en.wikipedia.org/wiki/SI_derived_unit)) for numerical values.

# %%
# 🔓
L = 50 / 100
Rw = 30 / 100

# %% [markdown]
# ### Graphical Representation
#
# 🧩 Implement a function `draw_wheelchair` with arguments `x`, `y` and `theta` that draws a simple geometric model of the wheelchair (with seat and fixed wheels) in the plane (top view) for arbitrary values of $(x, y)$ and $\theta$.
#
# 🗝️ **Hint.** Use the function `plot` of `matplotlib.pyplot`.

# %%
# 🔓
def draw_wheelchair(x, y, theta):
    translation = array([[x], [y]])
    rotation = array([
        [cos(theta), -sin(theta)], 
        [sin(theta),  cos(theta)]
    ])

    # Seat
    corners = [[0, -L/2], [L, -L/2], [L, +L/2], [0, L/2]]
    corners += [corners[0]]
    corners = array(corners).T
    corners = rotation @ corners + translation
    xc = corners[0]
    yc = corners[1]
    fill(xc, yc, color="#868e96", zorder=10)
    
    # Fixed Wheels
    wheel_left_xy_start = rotation @ [[-Rw], [-L/2]] + translation 
    wheel_left_xy_end = rotation @ [[Rw], [-L/2]] + translation
    plot([wheel_left_xy_start[0], wheel_left_xy_end[0]], [wheel_left_xy_start[1], wheel_left_xy_end[1]], color="black",linewidth=5, zorder=20)

    wheel_right_xy_start = rotation @ [[-Rw], [+L/2]] + translation
    wheel_right_xy_end = rotation @ [[Rw], [L/2]] + translation
    plot([wheel_right_xy_start[0], wheel_right_xy_end[0]], [wheel_right_xy_start[1], wheel_right_xy_end[1]], color="black", linewidth=5, zorder=20)

# %% [markdown]
# 🧩 Represent the wheelchair when $(x, y, \theta) = (0, 0, 0), (2, 2, \pi/2), (0, 4, \pi), (-2, 2, 3\pi/2)$.
#
# 🗝️ **Hint.** Use the following `draw_arena` function beforehand.

# %%
def draw_arena(xmin, xmax, ymin, ymax):
    wh_ratio = (xmax - xmin) / (ymax - ymin)
    figsize = fig_width, fig_height = 16, 16 / wh_ratio
    figure(figsize=figsize)
    axes = gca()
    axes.axis([xmin, xmax, ymin, ymax])
    axes.set_aspect(1)
    xticks(arange(xmin, xmax+1, 1))
    yticks(arange(ymin, ymax+1, 1))
    grid(True)

# %%
# 🔓
draw_arena(-5, 5, -1, 5)
draw_wheelchair(0, 0, 0)
draw_wheelchair(2, 2, pi/2)
draw_wheelchair(0, 4, pi)
draw_wheelchair(-2, 2, 3*pi/2)

# %% [markdown]
# ### Kinematic Modeling
#
# We assume that we can control the wheels angular velocities $\omega_l = \dot{\phi}_l$ and $\omega_r = \dot{\phi}_r$ (this is a *kinematic* model of the wheelchair).
# We also assume that the wheelchair fixed wheels roll without slipping.
#
# 🧩 Establish the differential equations that relate $\dot{x}$,
# $\dot{y}$ and $\dot{\theta}$ with $\omega_l$ and $\omega_r$.

# %% [markdown]
# 🔓
# $$
# \begin{array}{rcl}
# \dot{x} &=& R_w  \frac{\omega_l + \omega_r}{2} \cos \theta \\
# \dot{y} &=& R_w  \frac{\omega_l + \omega_r}{2} \sin \theta \\
# \dot{\theta} &=& R_w  \frac{\omega_r - \omega_l}{L} \\
# \end{array}
# $$

# %% [markdown]
# ### Analysis
#
# 🧩 Show that if $\omega_l$ and $\omega_r$ are continuously differentiable functions of $(x, y, \theta)$ (which includes the case of constant inputs), this system is well-posed.

# %% [markdown]
# 🔓 The vector field is continuously differentiable as a composition of continuously differentiable functions, thus the IVP is well-posed.

# %% [markdown]
# 🧩 Show that if $\omega_l$ and $\omega_r$ are constants, the maximal solution associated to any initial state is global. Is is still true of $\omega_l$ and $\omega_r$ are arbitrary continuously differentiable functions of $(x, y, \theta)$ ?

# %% [markdown]
# 🔓 When the inputs are constant, it's pretty easy to prove that the derivatives of $x$, $y$ and $\theta$ with respect to $t$ are uniformly bounded ; thus $x$, $y$ and $\theta$ are bounded on any bounded time interval and therefore no finite-time blowup may happen: the maximal solution is global.
#
# The situation is different with state-dependent inputs; for example with $\omega_r = - \omega_l = 0.5 (L/R_w)  \theta^2$, we end up with $\dot{\theta}(t) = \theta(t)^2$ which has a finite-time blowup for some initial values of $\theta$. Thus, the maximal solution may not be global.

# %% [markdown]
# ### Vector Field
#
# In the sequel, `omega` is a function that computes the input vector $\omega := (\omega_l, \omega_r)$ given the time $t$ and $(x, y, \theta)$ (thus, it may depend on the time and/or on the system state if needed). For example:

# %%
def omega(t, xytheta):
    omega_l = (1 - L/4) * pi / Rw
    omega_r = (1 + L/4) * pi / Rw
    return array([omega_l, omega_r])

# %% [markdown]
# 🧩 Implement a function `fun(t, xytheta)` that computes $(\dot{x}, \dot{y}, \dot{\theta})$ given the time $t$ and $(x,y,\theta)$ (and implicitly the inputs $\omega$ computed by the function `omega`).

# %%
# 🔓
def fun(t, xytheta):
    x, y, theta = xytheta
    omega_l, omega_r = omega(t, xytheta)
    dx = Rw * 0.5 * (omega_l + omega_r) * cos(theta)
    dy = Rw * 0.5 * (omega_l + omega_r) * sin(theta)
    dtheta = Rw * (omega_r - omega_l) / L
    return array([dx, dy, dtheta])

# %% [markdown]
# ### Simulation Setup
#
# 🧩 Simulate the wheelchair dynamics for 4 seconds when $(x_0, y_0, \theta_0)(t=0) = (0.0, 0.0, 0.0)$,
# and the wheels velocities are the constants $\omega_l = (1 - L/4)  \pi / R \mbox{ rad/s}$ and $\omega_r = (1 + L/4)  \pi / R_w \mbox{ rad/s}$.
# (Compute the dense outputs.)

# %%
# 🔓
r = solve_ivp(fun=fun, t_span =(0.0, 4.0), y0=[0.0, 0.0, 0.0], dense_output=True)

# %% [markdown]
# 🧩 Use the simulation results to draw the graphs of $x(t)$, $y(t)$ and $\theta(t)$.

# %%
# 🔓
t = linspace(0.0, 4.0, 1000)
x, y, theta = r["sol"](t)
fig=figure(figsize=(15, 15))
ax1, ax2 = fig.subplots(2, 1, sharex=True)
ax1.grid(True)
ax1.plot(t, x, label="$x(t)$")
ax1.plot(t, y, label="$y(t)$")
ax1.legend()
ax2.grid(True)
ax2.plot(t, theta, label=r"$\theta(t)$", color="C2")
ax2.legend()
xlabel("time")
pass

# %% [markdown]
# 🧩 Use the simulation results to display the robot location every 0.5 second.

# %%
# 🔓
t = linspace(0.0, 4.0, 4*2+1)
sol_t = r["sol"](t)
draw_arena(-4, 4, -1, 5)
for x, y, theta in sol_t.T:
    draw_wheelchair(x, y, theta)

# %% [markdown]
# 🧩 What should be the analytical expression of $x(t)$, $y(t)$ and $\theta(t)$?

# %% [markdown]
# $\theta(t) = 2 \pi / 4.0$, $x(t) = 2\sin(2\pi t / 4)$ and $y(t) = -2 \cos(2\pi t / 4)+2$.

# %% [markdown]
# 🧩 Do you experimental results match the theoretical results ? Draw the curves of the simulation error at time $t$ for $x$, $y$ and $\theta$.

# %%
t = linspace(0.0, 4.0, 1000)
x_t, y_t, theta_t = r["sol"](t)
fig=figure(figsize=(15, 15))
ax1, ax2 = fig.subplots(2, 1, sharex=True)
ax1.grid(True)
ax1.plot(t , x_t - 2*sin(2*pi*t/4), label="$x(t)$ error")
ax1.plot(t , y_t + 2*cos(2*pi*t/4) - 2, label="$y(t)$ error")
ax1.legend()
ax2.grid(True)
ax2.plot(t, theta_t - 2*pi*t / 4.0, label=r"$\theta(t)$ error")
ax2.legend()
xlabel("time")
pass

# %% [markdown]
# 🧩 If needed, adjust the simulation parameters until this error is uniformly less than $2 \times 10^{-5}$ for every component of $(x, y, \theta)$.

# %%
r = solve_ivp(
    fun=fun, 
    t_span=(0.0, 4.0), 
    y0=[0.0, 0.0, 0.0], 
    rtol=1e-6, 
    atol=1e-12, 
    dense_output=True
)
t = linspace(0.0, 4.0, 1000)
x_t, y_t, theta_t = r["sol"](t)
fig=figure(figsize=(15, 15))
ax1, ax2 = fig.subplots(2, 1, sharex=True)
ax1.grid(True)
ax1.plot(t , x_t - 2*sin(2*pi*t/4), label="$x(t)$ error")
ax1.plot(t , y_t + 2*cos(2*pi*t/4) - 2, label="$y(t)$ error")
ax1.legend()
ax2.grid(True)
ax2.plot(t, theta_t - 2*pi*t / 4.0, label=r"$\theta(t)$ error")
ax2.legend()
xlabel("time")
pass

# %% [markdown]
# Step 2 - Control Implementation
# ===============================

# %% [markdown]
# Time dependent inputs
# ---------------------

# %% [markdown]
# We are going to simulate the case of the chariot controlled by time-dependent angular velocities $\omega_l$ and $\omega_r$.
# We want a simulation lasting 5 seconds with the following inputs:
# $$
#     \omega_l(t) = \left\{
#        \begin{array}{rl}
#            (1 - L/4) \pi / R_w & \mbox{when $t \leq 1s$ or $t \geq 3$,} \\
#            (1 + L/4) \pi / R_w & \mbox{otherwise.}
#        \end{array}
#     \right.
# $$
# and
# $$
#     \omega_r(t) = \left\{
#        \begin{array}{rl}
#            (1 + L/4) \pi / R_w & \mbox{when $t \leq 1s$ or $t \geq 3$,} \\
#            (1 - L/4) \pi / R_w & \mbox{otherwise.}
#        \end{array}
#     \right.
# $$

# %% [markdown]
# ##### 🧩 Provide the new definition of `omega`

# %%
def omega(t, xytheta):
    if t <= 1 or t>=3:
        omega_l = (1 - L/4) * pi / Rw
        omega_r = (1 + L/4) * pi / Rw
    else:
        omega_l = (1 + L/4) * pi / Rw
        omega_r = (1 - L/4) * pi / Rw
    return array([omega_l, omega_r])

# %% [markdown]
# ##### 🧩 Make a simulation of 4s of the robot with the previous input. Use the `rtol` and `atol` that used to guarantee a precision of $2 \times 10^{-5}$ and by using the `dense_output` option to evaluate the solution at timesteps that will be defined later.
#
# 🗝️ **Hint.** It is not necessary to define again the function `fun`. If the previous cell has been correctly validated, `fun` will use the new definition of `omega`.

# %%
r = solve_ivp(
    fun=fun, 
    t_span=(0.0, 4.0), 
    y0=[0.0, 0.0, 0.0], 
    rtol=1e-6, 
    atol=1e-12, 
    dense_output=True)

# %% [markdown]
# 🧩 Use the simulation results to display the robot location every 0.5 seconds.

# %%
draw_arena(-2, 10, -2, 10)
t = linspace(0.0, 4.0, 4*2+1)
solution_n = r["sol"](t)
for x, y, theta in solution_n.T:
    draw_wheelchair(x, y, theta)

# %% [markdown]
# ## Analysis of the system at rest

# %% [markdown]
# ### Equilibrium

# %% [markdown]
# ##### 🧩 Show that for a suitable (constant) choice $\omega_e \in \mathbb{R}^2$ of the vector input $\omega$, the state $X_e = (x_e, y_e, \theta_e) = (0,0,0)$ is an equilibrium of the wheelchair kinematic model.

# %% [markdown]
# **Answer:**

# %% [markdown]
# En supposoant que Xe est un point d'équilibre, il faut que fun(Xe)=(0,0,0)
# Alors: $$
# \begin{array}{rcl}
# \dot{x} &=& Rw  \frac{\omega_l + \omega_r}{2}=0\\ donc \qquad \omega_l = - \omega_r \qquad (1)
# \\\dot{y} =0 \qquad puisque  \qquad  sin {\theta} =0 \\
# \end{array}
# $$
#
#
# $$
# \begin{array}{rcl}
#  et \dot{\theta} &=& R_w  \frac{\omega_r - \omega_l}{L} =0\\ donc \qquad \omega_l =  \omega_r \qquad (2)
# \end{array}
# $$
# Ainsi, de (1) et (2) :
# $$
# \begin{array}{rcl}
# \\\omega_l = \omega_r=0\\
# \end{array}
# $$

# %% [markdown]
# ##### 🧩 Show that for any other $\omega_e$, the system has no equilibrium.

# %% [markdown]
# **Answer:**

# %% [markdown]
# 1. Si  $\omega_r\neq 0$ ou $\omega_l\neq 0$:
#
#
# En supposant que le systeme admet un point d'equilibre Xe:
# Donc $\dot{x}=\dot{y}=0$ et sachant que $\omega_l\neq-\omega_r$ , on se retrouve avec $\cos\theta=\sin\theta=0$ ce qui est absurde . Donc le systeme n'admet pas de point d'equilibre.
#
# 2. Si  $\omega_r\neq 0$ et $\omega_l\neq 0$:
#
# Donc soit $\omega_l\neq-\omega_r$ ce qui nous donne la meme chose que ci-dessus,
# Soit  $\omega_l=-\omega_r$ et donc  $\dot{\theta} = 2\omega_r\frac {Rw}L \neq 0$
#
# Ainsi le systeme n'admet pas de point d'equilibre

# %% [markdown]
# ##### 🧩 Conversely, if $\omega = \omega_e$, what are the other equilibria of the system?

# %% [markdown]
# **Answer:**

# %% [markdown]
# Si $\omega=\omega_e$=0, alors pour tout point X,f(X) = 0. Chaque position est un point d'équilibre.

# %% [markdown]
# ### Linearized System Model
#
#
# Let $\omega = \omega_e$ and $X_e = (0,0,0)$. Let us introduce the the error variable $\Delta X = (\Delta x, \Delta y, \Delta \theta) = X - X_e$ and $\Delta \omega = \omega - \omega_e$.

# %% [markdown]
# ##### 🧩 Compute the corresponding linearized dynamics and put it in standard form: compute the matrices $A$ and $B$ (remember that $\omega = (\omega_l,\omega_r)$).

# %% [markdown]
# **Answer:**

# %% [markdown]
#  On a :
# $$
# \begin{pmatrix} \Delta \dot{x} \\ \Delta \dot{y} \\ \Delta \dot{\theta} \end{pmatrix} = A \begin{pmatrix} \Delta x \\ \Delta y \\ \Delta \theta \end{pmatrix} + B \begin{pmatrix} \Delta \omega_l \\ \Delta \omega_r \end{pmatrix}
# $$
# On obtient :
# $$
# A = \begin{pmatrix} 0 & 0 & 0 \\ 0 & 0 & 0 \\ 0 & 0 & 0 \end{pmatrix}et:\quad
# B = \begin{pmatrix} \frac{R_w}{2} & \frac{R_w}{2} \\ 0 & 0 \\ -\frac{R_w}{L} & \frac{R_w}{L} \end{pmatrix}
# $$

# %% [markdown]
# ### Stability of the linearized system

# %% [markdown]
# ##### 🧩 Is the linearized system asymptotically stable around $(0,0,0)$ when $\Delta \omega = (0,0)$ ?

# %% [markdown]
# **Answer:**

# %% [markdown]
# On a  $\dot X = A.X$ et A est à  3 valeurs propres nulles donc 𝐴 transforme au moins trois vecteurs différents en vecteurs nuls. Si on considere les vecteurs comme des états possibles du système. Donc ce systeme est instable.
#
# Pour qu'il soit stable : Si nous formulons les valeurs propres de cette façon : 𝜆 = 𝜆ᵣ + 𝑖𝜆ᵢ, où 𝜆ᵣ est la partie réelle, tel que 𝜆ᵣ est strictement négatif pour chaque valeur propre : les solutions du système convergent vers zéro lorsque le temps passe, ce qui signifie que le système atteint un état d'équilibre stable.

# %% [markdown]
# ##### 🧩 Is the original system asymptotically stable ? Or even (locally) attractive ?

# %% [markdown]
# 🔓 **Answer:**

# %% [markdown]
# Initialement, on a 𝜔=𝜔𝑒, cela signifie que le système ne change pas dans le temps et reste dans sa position initiale X0. Donc ∀𝑡>0, 𝑋(𝑡)=𝑋0.
#
#
# Si X0≠(0,0,0) , il ne se trouve pas dans sa position d'équilibre stable. Le systeme évoluera mais ne reviendra jamais à sa position d'équilibre stable, qui est l'origine du système.
# En conséquence, le système initial n'est pas attractif, même localement, et donc ne possède pas de point d'équilibre asymptotiquement stable; les solutions du système ne convergent pas vers l'origine même si le temps tend vers l'infini.

# %% [markdown]
# ### Controllability of the linearized system

# %% [markdown]
# In this section, we consider only the linearized system defined by the matrices $A$ and $B$ computed previously:
#
# $$
# \frac{\Delta X}{dt} = A \Delta X + B\Delta u
# $$

# %% [markdown]
# ##### 🧩 Is there an admissible trajectory that start with the state $X_0=(-2,0,0)$ and ends at origin after some time?

# %% [markdown]
# **Answer:**

# %% [markdown]
# On a :
# $$
# \Delta X = Xf - Xi = (2,0,0)
# $$
# et : A = 0
# Donc l'équation devient :
# $$
# \begin{pmatrix} \frac{\Delta x}{dt} \\ 0 \\ 0 \end{pmatrix} = \begin{pmatrix} \frac{R_w}{L}(\omega_l+\omega_r) \\ 0 \\ \frac{R_w}{L}(\omega_r-\omega_l) \end{pmatrix}
# $$
# On obtient :
# $$
# \omega_r = \omega_l = \frac{2}{Rw.\Delta t}
# $$
# Donc : Oui, avec $\omega_r=\omega_l$ le robot se déplacera suivant l'axe X et arrivera à l'origine du repère après un certain temps t

# %% [markdown]
# ##### 🧩 Is there an admissible trajectory that start with the state $X_0=(0,2,0)$ and ends at origin after some time?

# %% [markdown]
# **Answer:**

# %% [markdown]
# De même, on a :
# $$
# \Delta X = Xf - Xi = (0,-2,0)
# $$
# Donc l'équation devient :
# $$
# \begin{pmatrix} 0 \\ \frac{\Delta y}{dt} \\ 0 \end{pmatrix} = \begin{pmatrix} \frac{R_w}{L}(\omega_l+\omega_r) \\ 0 \\ \frac{R_w}{L}(\omega_r-\omega_l) \end{pmatrix}
# $$
# On obtient :
# $\omega_l = -\omega_r$ et : $\omega_l = \omega_r$, ce qui est absurde.
#
# De plus, $\omega_r$ et $\omega_l$ n'interviennent pas dans $\dot{\Delta Y}$, donc on ne peut jamais atteindre l'origine où y=0.

# %% [markdown]
# ##### 🧩 Is the linearized system controllable?

# %% [markdown]
# **Answer:**

# %% [markdown]
# Nous pouvons vérifier le rang de la matrice de contrôlabilité C, qui est donnée par:
# Puisque A est nulle alors
# $$
# C =[B]
# $$
#
# Donc puisque C a le meme rang que B (2), le système n'est pas contrôlable.

# %% [markdown]
# ## Control on a straight line
#
# ### Admissible trajectories

# %% [markdown]
# Let $x_R(t) = v t$ and $y_R(t) = 0$ where $v \in \mathbb{R}$ and $v \neq 0$.

# %% [markdown]
# ##### 🧩 Determine the set of trajectories $X_R(t) = (x_R(t), y_R(t), \theta_R(t))$ which are admissible and compute the corresponding reference control $\omega_{R}(t)$.

# %% [markdown]
# **Answer:**

# %% [markdown]
# Sachant que $\begin{array}{rcl} \dot{y} &=& R_w  \frac{\omega_l + \omega_r}{2} \sin \theta \\ \end{array}$ et ici, $y_R(t) = 0$ donc $\sin\theta_R = 0$ ou $(\omega_l+\omega_r)/2$=0.
#
# Si on prend la 2eme possibilité, on se trouve avec $\dot{x}$=0, ce qui est absurde. Donc $\sin\theta_R = 0$.
#
# Ainsi $\theta_R(t) = k\pi$. Par consequent, $\dot\theta=0$ et $\omega_l(t)=\omega_r(t)=\omega(t)$
#
# Et donc $\dot x = R_w\omega(t)\cos k\pi$
#
# Jusqu'à présent  : $y_R(t) = 0$ et  $\theta_R(t) = k\pi$ qui revient aux cas $\theta_R(t) = 0$ ou $\theta_R(t) = \pi$ et $x_R(t) = vt$
#
# Finalement, $X_R(t) =(vt,0,0)$ donc $\omega_R(t)=(v/R_w,v/R_w)$
# ou  $X_R(t) =(vt,0,\pi)$ donc $\omega_R(t)=(-v/R_w,-v/R_w)$

# %% [markdown]
# ### Linearized system

# %% [markdown]
# Let $\Delta X(t) = X(t) - X_R(t)$ and $\Delta \omega(t) = \omega(t) - \omega_R(t)$.

# %% [markdown]
# ##### 🧩 Compute the linearized dynamics of the system for the class of trajectory "moving forward".

# %% [markdown]
# **Answer:**

# %% [markdown]
# $$
# \begin{pmatrix} \Delta \dot{x} \\ \Delta \dot{y} \\ \Delta \dot{\theta} \end{pmatrix} = A \begin{pmatrix} \Delta x \\ \Delta y \\ \Delta \theta \end{pmatrix} + B \begin{pmatrix} \Delta \omega_l \\ \Delta \omega_r \end{pmatrix}
# $$
# On obtient :
# $$
# A = \begin{pmatrix} 0 & 0 & 0 \\ 0 & 0 & v \\ 0 & 0 & 0 \end{pmatrix}et:\quad
# B = \begin{pmatrix} \frac{R_w}{2} & \frac{R_w}{2} \\ 0 & 0 \\ -\frac{R_w}{L} & \frac{R_w}{L} \end{pmatrix}
# $$

# %% [markdown]
# ##### 🧩 Is the system asymptotically stable, with $\Delta\omega(t)=0$?

# %% [markdown]
# **Answer:**

# %% [markdown]
# La matrice A a encore une fois 3 valeurs propres nulles donc le systeme n'est pas asymptotiquement stable.

# %% [markdown]
# ##### 🧩 Is the system attractive, with $\Delta\omega(t)=0$?

# %% [markdown]
# **Answer:**

# %% [markdown]
#  Δ𝑦 reste constante sans correction , cela signifie que le système n'est pas capable de corriger la déviation du point d'équilibre, ce qui est un signe que le système n'est pas stable. Par conséquent, le système n'est pas localement attractif.

# %% [markdown]
# ##### 🧩 Show that the linearized system is controllable.

# %% [markdown]
# **Answer:**

# %% [markdown]
# On prend la matrice de contrôlabilité pour etudier son rang ,$C = [B, AB]$ puisque $A^2=0$
#
#
#
# $$C=
# \begin{bmatrix}
#     \frac {R_w}2 & \frac {R_w}2 & 0 & 0 \\
#     0 & 0 & -v \frac {R_w}L & v \frac {R_w}L \\
#     -\frac {R_w}2 & \frac {R_w}2 & 0 & 0
# \end{bmatrix}
# $$
#
# La matrice de contrôlabilité est de rang plein donc le système est contrôlable

# %% [markdown]
# ### Linearized system implementation

# %% [markdown]
# In the sequel, we will use $v=4.8 \mbox{ km/h}$.

# %% [markdown]
# ##### 🧩 Implement and print the matrices $A$ and $B$

# %%
v=4.8/3.6
A = array([[0,0,0],[0,0,v],[0,0,0]])
B = array([[Rw/2,Rw/2],[0,0],[-Rw/L,Rw/L]])
print("A=",A)
print("B=",B)
# Out:
# A= [[0.         0.         0.        ]
#  [0.         0.         1.33333333]
#  [0.         0.         0.        ]]
# B= [[ 0.15  0.15]
#  [ 0.    0.  ]
#  [-0.6   0.6 ]]

# %% [markdown]
# The linear model has to be fed with some $\Delta\omega$ input. Like for the nonlinear system, we define a function $\Delta\omega(t,\Delta_X)$ that computes the input of the linearized system. For example, if we do not want any correction to the reference input, we set:

# %%
def deltaOmega(t, deltaX):
    return array([0, 0])

# %% [markdown]
# ##### 🧩 Using this function `deltaOmega`, define a function `lin_fun` that computes $d{\Delta X}/dt$ given the arguments `t` and `deltaX`$.

# %%
def lin_fun(t, deltaX):
    DeltaX = A@deltaX
    DeltaO = B@deltaOmega(t,deltaX)
    return DeltaX+DeltaO

# %% [markdown]
# ### Controller Design on the linearized system

# %% [markdown]
# ##### 🧩 Implement a process that computes a gain matrix $K$ that places the poles of the linearized system at some arbitrary location.
#
# For this question, we will chose 3 real poles close to -0.5.
#
# Then, print the poles of the closed-loop system
#
# $$
# \frac{d\Delta X}{dt}= A \Delta X + B\Delta\omega
# \; \mbox{ with } \;
# \Delta\omega = -K \Delta X.
# $$

# %%
poles = np.array([-0.51, -0.52, -0.53])

# Compute gain matrix
K = place_poles(A, B, poles).gain_matrix
print(K)
CL_poles = eigvals(A - B@K)
print("Poles of closed-loop system:", real(CL_poles))
# Out:
# [[ 1.7333333  -0.16787812 -0.86397605]
#  [ 1.73333336  0.16999688  0.86935729]]
# Poles of closed-loop system: [-0.52 -0.53 -0.51]

# %% [markdown]
# ##### 🧩 Simulate the linearized system during 20s, with the initial condition $\Delta X(0) = (0,2,0)$.

# %%
def deltaOmega(t,deltaX):
    return -K@deltaX

t1 = 20
r = solve_ivp(fun=lin_fun,t_span=[0,t1],y0=[0,2,0],dense_output=True, rtol=1e-6, atol=1e-12)

# %% [markdown]
# 🧩 Plot the values of $\Delta x(t)$, $\Delta y(t)$ and $\Delta\theta(t)$ (**plot $\Delta\theta(t)$ in degrees**)

# %%
t = linspace(0.0,t1, 500)
dx, dy, dtheta = r["sol"](t)
fig=figure(figsize=(12, 12))
ax1, ax2 = fig.subplots(2, 1, sharex=True)
ax1.grid(True)
ax1.plot(t, dx, label="$\Delta x(t)$")
ax1.plot(t, dy, label="$\Delta y(t)$")
ax1.legend()
ax2.grid(True)
ax2.plot(t, dtheta*180/pi, label=r"$\Delta\theta(t)$")
ax2.legend()
pass

# %% [markdown]
# ##### 🧩 Why is it important to check that $\Delta\theta(t)$ stays small ?

# %% [markdown]
# **Answer:**

# %% [markdown]
# Pour que le systeme reste sur une trajectoire lineaire, il faut que l'erreur $\Delta\theta(t)$ soit petite puisque $\theta$ est responsable de l'orientation de la chaise roulante.

# %% [markdown]
# ##### 🧩 Compute the corresponding values of $\Delta\omega_l,\Delta\omega_r$ and store them in the Python variables `dOmega_l`, `dOmega_r`

# %%
dX = r["sol"](t)
dOmega = -K@dX
dOmega_l = dOmega[0]
dOmega_r = dOmega[1]
# print(dOmega_l,dOmega_r)

# %% [markdown]
# ##### 🧩 Compute $\omega_l,\omega_r$ and plot the translation speed of each wheels in km/h

# %%
omega_l = dOmega_l +v/Rw
omega_r = dOmega_r +v/Rw

fig=figure(figsize=(12, 12))
plot(t,omega_l*Rw*3.6, label=r"Vitesse de la roue gauche (km/h)")
plot(t,omega_r*Rw*3.6, label=r"Vitesse de la roue droite (km/h)")
grid()
legend()

# %% [markdown]
# ##### 🧩 Are these control values consistent with what the robot should do to cancel the error?

# %% [markdown]
# **Answer:**

# %% [markdown]
# Au début, la chaise était située sur un y>0. La roue gauche tourne plus rapidement que l'autre roue pour pouvoir tourner à droite et rejoindre l'axe (Ox). Les roues doivent par suite toutes les deux converger vers la vitesse 4.8 km/h pour continuer sur une trajectoire linéaire, ce qui est le cas sur le graphe.

# %% [markdown]
# ###  Controller Tuning

# %% [markdown]
# ##### 🧩 Tune the poles (and recompute the gain matrix) so that the actual location $(x, y)$ is within 10 cm of the desired location within 20 sec and the linear velocity of each wheel never exceeds $5$ km/h. Plot the values of $\Delta x$ (in m), $\Delta y$ (in m), $\Delta \theta$ (in degrees), and the speed of each wheel (in km/h)

# %%
poles = [-0.36,-0.37,-0.38] # Strictly negative real part
K = place_poles(A,B,poles).gain_matrix

t2 = 20
r = solve_ivp(fun=lin_fun,t_span=[0,t2],y0=[0,2,0],dense_output=True, rtol=1e-6, atol=1e-12)

t = linspace(0.0,t2, 100)
dx, dy, dtheta = r["sol"](t)
fig=figure(figsize=(12, 12))
ax1, ax2, ax3 = fig.subplots(3, 1, sharex=True)
ax1.grid(True)
ax1.plot(t, dx, label="$\Delta x(t)$")
ax1.plot(t, dy, label="$\Delta y(t)$")
ax1.legend()
ax2.grid(True)
ax2.plot(t, dtheta*180/pi, label=r"$\Delta\theta(t)$")
ax2.legend()

dX = r["sol"](t)
dOmega = -K@dX
dOmega_l = dOmega[0]
dOmega_r = dOmega[1]
omega_l = dOmega_l +v/Rw
omega_r = dOmega_r +v/Rw

ax3.plot(t,omega_l*Rw*3.6, label=r"Vitesse de la roue gauche (km/h)")
ax3.plot(t,omega_r*Rw*3.6, label=r"Vitesse de la roue droite (km/h)")
ax3.legend()
ax3.grid()

# %% [markdown]
# ##### 🧩 Simulate the initial, nonlinear wheelchair model when the control law computed in the section "Controller Tuning" is applied. Check that the constraint given for the control law design still hold.

# %%
poles = [-0.36,-0.37,-0.38] # Strictly negative real part
K = place_poles(A,B,poles).gain_matrix

t2 = 20
r = solve_ivp(fun=fun,t_span=[0,t2],y0=[0,2,0],dense_output=True, rtol=1e-6, atol=1e-12)

t = linspace(0.0,t2, 100)
dx, dy, dtheta = r["sol"](t)
fig=figure(figsize=(12, 12))
ax1, ax2, ax3 = fig.subplots(3, 1, sharex=True)
ax1.grid(True)
ax1.plot(t, dx, label="$\Delta x(t)$")
ax1.plot(t, dy, label="$\Delta y(t)$")
ax1.legend()
ax2.grid(True)
ax2.plot(t, dtheta*180/pi, label=r"$\Delta\theta(t)$")
ax2.legend()

dX = r["sol"](t)
dOmega = -K@dX
dOmega_l = dOmega[0]
dOmega_r = dOmega[1]
omega_l = dOmega_l +v/Rw
omega_r = dOmega_r +v/Rw

ax3.plot(t,omega_l*Rw*3.6, label=r"Vitesse de la roue gauche (km/h)")
ax3.plot(t,omega_r*Rw*3.6, label=r"Vitesse de la roue droite (km/h)")
ax3.legend()
ax3.grid()

# %% [markdown]
# ##### 🧩 Display this trajectory using a snapshot of the wheelchair in the plane every second.

# %%
t2 = 20
r = solve_ivp(fun=fun,t_span=[0,t2],y0=[0,2,0],dense_output=True, rtol=1e-6, atol=1e-12)

draw_arena(-10, 15, -10, 10)
t = linspace(0.0, t2, t2)
solution_n = r["sol"](t)
for x, y, theta in solution_n.T:
    draw_wheelchair(x, y, theta)
